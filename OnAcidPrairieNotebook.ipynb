# %%
import obtain_components as oc
import OnAcid_Prairie_holo as oap
import os
# Out:
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\ndimage\morphology.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[slc] = structure != 0
# Detected iPython

# %%
folder = 'F:\\VivekNuria\\'
animal = 'a1'
day = 'd4'
fr = 30.448
dims = [512, 512]

# %%
fnames = [os.path.join(folder, animal, day, 'im\\test_holostim','d4holo.tif')]
fnames
os.path.exists(fnames[0])
# Out:
# True

# %%
estimates = oap.obtain_spatial_filters(fnames, fr, True)
# Out:
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\ndimage\morphology.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[slc] = structure != 0
# WARNING:root:Changing key fnames in group data from None to ['F:\\VivekNuria\\a1\\d4\\im\\test_holostim\\d4holo.tif']
# WARNING:root:Changing key decay_time in group data from 0.4 to 0.75
# WARNING:root:Changing key rf in group patch from None to 24
# WARNING:root:Changing key stride in group patch from None to 12
# WARNING:root:Changing key p_tsub in group patch from 2 to 5
# WARNING:root:Changing key gSig in group init from [5, 5] to (4, 4)
# WARNING:root:Changing key K in group init from 30 to 4
# WARNING:root:Changing key tsub in group init from 2 to 5
# WARNING:root:Changing key nIter in group init from 5 to 3
# WARNING:root:Changing key max_iter_snmf in group init from 500 to 100
# WARNING:root:Changing key SNR_lowest in group quality from 0.5 to 1
# WARNING:root:Changing key rval_lowest in group quality from -1 to 0.2
# WARNING:root:Changing key cnn_lowest in group quality from 0.1 to 0.2
# WARNING:root:Changing key init_method in group online from bare to cnmf
# WARNING:root:Changing key sniper_mode in group online from False to True
# WARNING:root:Changing key thresh_CNN_noisy in group online from 0.5 to 0.8
# WARNING:root:Changing key max_shifts_online in group online from 10 to 6
# WARNING:root:Changing key expected_comps in group online from 500 to 100
# WARNING:root:Changing key update_freq in group online from 200 to 500
# Size frame:(512, 512)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\mmapping.py:418: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Yr = Yr[slices]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# WARNING:root:Changing key medw in group spatial from None to (3, 3)
# WARNING:root:Changing key se in group spatial from None to [[1 1 1]
#  [1 1 1]
#  [1 1 1]]
# WARNING:root:Changing key ss in group spatial from None to [[1 1 1]
#  [1 1 1]
#  [1 1 1]]
# WARNING:root:Changing key n_pixels_per_process in group preprocess from None to 262144
# WARNING:root:Changing key n_pixels_per_process in group spatial from None to 262144
# WARNING:root:Changing key n_pixels_per_process in group preprocess from 262144 to 576
# WARNING:root:Changing key n_pixels_per_process in group spatial from 262144 to 576
# (48, 48)
# WARNING:root:Changing key rf in group patch from 24 to None
# WARNING:root:Changing key stride in group patch from 12 to None
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# ...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\numpy\core\memmap.py:335: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   res = super(memmap, self).__getitem__(index)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:386: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dims_sliced = images[indeces].shape[1:]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py:389: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   images = images[indeces]
# WARNING:root:Parallel processing in a single patch                            is not available for loaded in memory or sliced                            data.
# checking if missing data
# Noise Normalization
# Spatial Downsampling 2-photon
# ***** OPENCV!!!!
# Roi Extraction...
# Greedy initialization of spatial and temporal components using spatial Gaussian filtering
# USING ROLLING SUM FOR INITIALIZATION....
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:635: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]].copy(), dtype=np.float32)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:650: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   Y[[slice(*a) for a in ijSig]] -= dataSig.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:657: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   dataTemp[[slice(*a) for a in Lag]] = coef
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:661: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rho[[slice(*a) for a in Mod]] -= temp.copy()
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:664: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rolling_filter, 1., rho[[slice(*a) for a in Mod]]**2)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\initialization.py:665: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   v[[slice(*a) for a in Mod]] = np.amax(rho_filt, axis=-1)
# (Hals) Refining Components...
# 20.91719651222229
# Transforming patches into full matrix
# Skipped %d Empty Patch 0
# Generating background
# Compressing background components with a low rank NMF
# Generating background DONE
# merging
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\sparse\compressed.py:746: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)
# [656 657 659 662 663 664 666 712 713 714 716 717 718 719 720 721 723]
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\signal\spectral.py:1773: UserWarning: nperseg = 256 is greater than input length  = 200, using nperseg = 200
#   .format(nperseg, input_length))
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\deconvolution.py:991: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   g = np.linalg.lstsq(A, xc[lags + 1:])[0]
# [140 141 144 196 197 200 202]
# [544 546 549 600 601 603 604 606 660 661]
# [ 92  96  97  98 148 152 153 154]
# [512 514 518 568 570 573]
# [109 110 164 165 166 167 223]
# [616 620 621 672 676]
# [765 767 768 769 770 771 772 775]
# [422 424 426 476 480]
# [537 543 592 595 599]
# [  2   4  57  60  61 118]
# [32 33 34 36 37]
# [ 44  48 100 104 106]
# [641 644 697 700]
# [145 149 201 206]
# [13 15 16 17 18]
# [624 628 681 684]
# [120 125 177 180]
# [227 228 282 284]
# [ 77  80 132 136]
# [208 264 266 268]
# [776 777 778 782 783]
# [176 232 236 237]
# [605 607 608 610]
# [428 429 430 432]
# [507 510 564]
# [513 565 569]
# [105 108 161]
# [397 400 458]
# [709 710 715]
# [117 171 172]
# [416 419 472]
# [448 449 452]
# [119 123 175]
# [668 724 726]
# [209 212 214]
# [531 584 588]
# [733 736 737]
# [62 63 65]
# [349 401 404]
# [248 249 252]
# [68 69 72]
# [464 465 470]
# [560 561 562]
# [366 420 423]
# [182 185 242]
# [437 438 493]
# [156 160]
# [754 756]
# [504 509]
# [304 309]
# [516 572]
# [677 732]
# [41 46]
# [692 748]
# [84 88]
# [640 696]
# [216 222]
# [632 688]
# [525 528]
# [483 486]
# [508 515]
# [50 55]
# [485 489]
# [540 545]
# [320 378]
# [548 552]
# [699 752]
# [205 211]
# [475 478]
# [577 582]
# [64 70]
# [369 372]
# [142 198]
# [238 240]
# [678 680]
# [434 436]
# [463 467]
# [82 87]
# [150 204]
# [410 413]
# [368 425]
# [589 593]
# [217 221]
# [241 244]
# [722 727]
# [310 364]
# [634 637]
# [498 502]
# [653 658]
# [215 218]
# [622 626]
# [553 557]
# [596 602]
# [155 158]
# [455 457]
# [338 342]
# [327 329]
# [459 460]
# [382 384]
# [28 29]
# [272 277]
# [689 693]
# [168 224]
# [24 30]
# [392 396]
# [780 781]
# [341 344]
# [39 42]
# [654 708]
# [297 300]
# [351 353]
# [462 517]
# [613 614]
# [583 585]
# [7 9]
# [471 474]
# [207 262]
# [631 635]
# [322 324]
# [728 729]
# [295 346]
# [290 292]
# [444 500]
# [303 356]
# [183 239]
# [19 21]
# [126 128]
# [75 79]
# [773 779]
# [12 14]
# [178 235]
# [761 766]
# [355 358]
# [427 431]
# [194 199]
# [ 0 58]
# [293 350]
# [639 694]
# [210 265]
# [385 389]
# [26 31]
# [271 274]
# [647 650]
# [331 333]
# [395 400 423 452 500 503]
# [216 402 438 512]
# [380 401 444 471]
# [ 28 419 505]
# [378 407 467]
# [388 416]
# [399 484]
# [393 508]
# [453 469]
# [424 454]
# [410 483]
# [422 464]
# [396 408]
# No neurons merged!
# Generating residuals
# entering the deconvolution
# 177 out of total 500 temporal components updated
# 321 out of total 500 temporal components updated
# 425 out of total 500 temporal components updated
# 482 out of total 500 temporal components updated
# 499 out of total 500 temporal components updated
# 500 out of total 500 temporal components updated
# 177 out of total 500 temporal components updated
# 321 out of total 500 temporal components updated
# 425 out of total 500 temporal components updated
# 482 out of total 500 temporal components updated
# 499 out of total 500 temporal components updated
# 500 out of total 500 temporal components updated
# stopping: overall temporal component not changing significantly
# WARNING:root:Changing key expected_comps in group online from 100 to 705
# Expecting 705 components
# Using TensorFlow backend.
# Now processing file F:\VivekNuria\a1\d4\im\test_holostim\d4holo.tif
# Epoch: 1. 200 frames have beeen processed in total. 0 new components were added. Total # of components is 500
# Epoch: 1. 300 frames have beeen processed in total. 4 new components were added. Total # of components is 504
# Epoch: 1. 400 frames have beeen processed in total. 2 new components were added. Total # of components is 506
# Epoch: 1. 500 frames have beeen processed in total. 2 new components were added. Total # of components is 508
# Epoch: 1. 600 frames have beeen processed in total. 0 new components were added. Total # of components is 508
# Updating Shapes
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\online_cnmf.py:1247: RuntimeWarning: invalid value encountered in true_divide
#   ((CY[m, ind_pixels] - Ab_dense[ind_pixels].dot(CC[m])) / CC[m, m]), 0)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\online_cnmf.py:1247: RuntimeWarning: invalid value encountered in maximum
#   ((CY[m, ind_pixels] - Ab_dense[ind_pixels].dot(CC[m])) / CC[m, m]), 0)
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\online_cnmf.py:1249: RuntimeWarning: invalid value encountered in greater
#   if tmp.dot(tmp) > 0:
# Epoch: 1. 700 frames have beeen processed in total. 2 new components were added. Total # of components is 510
# Epoch: 1. 800 frames have beeen processed in total. 0 new components were added. Total # of components is 510
# Epoch: 1. 900 frames have beeen processed in total. 2 new components were added. Total # of components is 512
# Epoch: 1. 1000 frames have beeen processed in total. 0 new components were added. Total # of components is 512
# Epoch: 1. 1100 frames have beeen processed in total. 2 new components were added. Total # of components is 514
# Updating Shapes
# Epoch: 1. 1200 frames have beeen processed in total. 1 new components were added. Total # of components is 515
# Epoch: 1. 1300 frames have beeen processed in total. 0 new components were added. Total # of components is 515
# Epoch: 1. 1400 frames have beeen processed in total. 1 new components were added. Total # of components is 516
# Epoch: 1. 1500 frames have beeen processed in total. 0 new components were added. Total # of components is 516
# Epoch: 1. 1600 frames have beeen processed in total. 0 new components were added. Total # of components is 516
# Updating Shapes
# Epoch: 1. 1700 frames have beeen processed in total. 0 new components were added. Total # of components is 516
# Epoch: 1. 1800 frames have beeen processed in total. 0 new components were added. Total # of components is 516
# Epoch: 1. 1900 frames have beeen processed in total. 4 new components were added. Total # of components is 520
# Epoch: 1. 2000 frames have beeen processed in total. 0 new components were added. Total # of components is 520
# Epoch: 1. 2100 frames have beeen processed in total. 1 new components were added. Total # of components is 521
# Updating Shapes
# Epoch: 1. 2200 frames have beeen processed in total. 0 new components were added. Total # of components is 521
# Epoch: 1. 2300 frames have beeen processed in total. 0 new components were added. Total # of components is 521
# Epoch: 1. 2400 frames have beeen processed in total. 0 new components were added. Total # of components is 521
# Epoch: 1. 2500 frames have beeen processed in total. 0 new components were added. Total # of components is 521
# Epoch: 1. 2600 frames have beeen processed in total. 1 new components were added. Total # of components is 522
# Updating Shapes
# Epoch: 1. 2700 frames have beeen processed in total. 0 new components were added. Total # of components is 522
# Epoch: 1. 2800 frames have beeen processed in total. 1 new components were added. Total # of components is 523
# Epoch: 1. 2900 frames have beeen processed in total. 0 new components were added. Total # of components is 523
# Epoch: 1. 3000 frames have beeen processed in total. 1 new components were added. Total # of components is 524
# Epoch: 1. 3100 frames have beeen processed in total. 0 new components were added. Total # of components is 524
# Updating Shapes
# 390.8893532752991
# USING MODEL:C:\Users\User\caiman_data\model\cnn_model.json
# 524/524 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 2ms/step

# %%
oc.obtain_components(folder, animal, day, estimates, dims)
# Out:
# C:\ProgramData\Anaconda3\envs\caiman\lib\site-packages\scipy\ndimage\measurements.py:1328: RuntimeWarning: invalid value encountered in double_scalars
#   for dir in range(input.ndim)]
# Success! shift was: [-0.7039533599080336, 3.113737000764449]
